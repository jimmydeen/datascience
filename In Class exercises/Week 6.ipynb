# %% [markdown]
# ## Week 6 Exercises

# %% [markdown]
# Note that all of the exercises use `mpg` dataset included in `Seaborn`. You will need to load this data before attempting them.

# %%
import seaborn as sns

cars= sns.load_dataset('mpg')

cars
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# Determine which region, on average, produced the most fuel efficient cars between the years 1970 and 1980. Hint: You will need to filter then plot the data. Several kinds of plots would be reasonable. After interpretting your plot, enter the region name as text.

# %%
car_year=cars.model_year
cars_between = cars[(car_year >= 70)&(car_year <= 80)]
region = cars.origin
sns.boxplot(data=cars_between, x=region, y='mpg')

'''Region = Japan'''
# Out:
# 'Region = Japan'

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Was the region you chose always producing the most fuel efficient cars? Using one line plot, show the change in vehicle mpg over the 10 year period for each region. Which years was the top region overall (from Ex.1) falling behind? (you can "eyeball" this from the plot). After interpretting your plot, enter the years as text.

# %%
sns.lineplot(data=cars_between, x= cars_between.model_year, y='mpg',hue=region)

'''Years = 1973, 1977, 1980'''
# Out:
# 'Years = 1973, 1977, 1980'

# %% [markdown]
# ### Exercise 3

# %% [markdown]
# Plot the relationship between horsepower and acceleration for all of the cars in the data and color the points by cylinder number. Change the default color map to a color map of your choice (see the documentation for how to do this). Interpret the plot, i.e, what relationships does it show? After plotting, enter your interpretation as text.

# %%
sns.scatterplot(data=cars, x='horsepower', y='acceleration', hue='cylinders', palette= 'rocket_r')

'''There is a negative correlation between acceleration and horsepower, that is, as horsepower increases, acceleration decreases. On average, cars with smaller cylinders have higher acceleration and less horsepower than cars with a higher number of cylinder'''
# Out:
# 'There is a negative correlation between acceleration and horsepower, that is, as horsepower increases, acceleration decreases. On average, cars with smaller cylinders have higher acceleration and less horsepower than cars with a higher number of cylinder'

# %% [markdown]
# ### Exercise 4

# %% [markdown]
# For only the continuous variables in the data, plot their relationships using `sns.pairplot`. For the two variables with the strongest relationship (heighest magnitude correlation value), plot a scatter plot with a regression line that summarizes their relationship. After plotting, enter your interpretation as text.

# %%
#continuous data is mpg, displacement, horsepower, weight, acceleration

continuous_cars = cars.drop(columns=['cylinders', 'model_year', 'origin', 'name'])

sns.pairplot(data=continuous_cars)

# %%
corr = cars.corr()
sns.heatmap(corr, annot=True, center=0, square=True, linewidths=.5);
#Highest correlation displacement and cylinders

# %%
sns.regplot(data=continuous_cars, x='weight', y='displacement')

'''Displacement is linearly correlated with the weight of the vehicle as seen from the graph, the plot points are very close to the mean particularly at the bottom end of the graph, where there are more data values to plot a more accurate mean. However the correlation is still almost linear, as weight increases, displacement increases.'''
# Out:
# 'displacement is almost linearly correlated with number of cylinders. As a car has more cylinders, the engine has more displacement.'
